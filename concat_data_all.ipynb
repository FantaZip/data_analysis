# %%
import pandas as pd

# %%
from google.oauth2 import service_account

credentials = service_account.Credentials.from_service_account_file("./EDA/data/key.json")

# %%
from google.cloud import bigquery

client = bigquery.Client(
    credentials=credentials,
    project=credentials.project_id
)

# %%
safe = '''
SELECT 
  T1.county_name,
  T1.town_name,
  T1.area,
  T1.pop_total,
  T1.pop_men,
  T1.pop_women,
  T1.men_2030,
  T1.women_2030,
  T2.cctv_num,
  COALESCE(T3.light_num, 0) AS light_num,
  COALESCE(T4.house_num, 0) AS house_num,
  COALESCE(T5.police_num, 0) AS police_num
FROM 
  (
    SELECT 
      pop.county_name,
      pop.town_name,
      sum(area.Subtotal) as area,
      SUM(pop.total) AS pop_total,
      sum(pop.men) as pop_men,
      sum(pop.women) as pop_women,
      SUM(_20_29_men) + SUM(_30_39_men) AS men_2030,
      SUM(_20_29_women) + SUM(_30_39_women) AS women_2030
    FROM 
      `my-fantazip.fantazip.population_by_age` AS pop
    inner join
      `my-fantazip.fantazip.town_area_final` AS area
    on
      pop.county_name = area.county_name
      and pop.town_name = area.town_name
    GROUP BY
      pop.county_name,
      pop.town_name
  ) AS T1
INNER JOIN
  (
    SELECT 
      county_name,
      town_name,
      SUM(install_num) AS cctv_num
    FROM 
      `my-fantazip.fantazip.cctv`
    GROUP BY
      county_name,
      town_name
  ) AS T2
ON
  T1.county_name = T2.county_name
  AND T1.town_name = T2.town_name
LEFT OUTER JOIN
  (
    SELECT 
      county_name,
      town_name,
      SUM(install_num) AS light_num
    FROM 
      `my-fantazip.fantazip.light`
    GROUP BY
      county_name,
      town_name
  ) AS T3
ON
  T1.county_name = T3.county_name
  AND T1.town_name = T3.town_name
LEFT OUTER JOIN
  (
    SELECT 
      county_name,
      town_name,
      COUNT(town_name) AS house_num
    FROM 
      `my-fantazip.fantazip.safety_house`
    GROUP BY
      county_name,
      town_name
  ) AS T4
ON
  T1.county_name = T4.county_name
  AND T1.town_name = T4.town_name
LEFT OUTER JOIN
  (
    SELECT 
      county_name,
      town_name,
      COUNT(town_name) AS police_num
    FROM 
      `my-fantazip.fantazip.police`
    GROUP BY
      county_name,
      town_name
  ) AS T5
ON
  T1.county_name = T5.county_name
  AND T1.town_name = T5.town_name
'''

# %%
safe = client.query(safe).to_dataframe()
safe
# Out:
#     county_name town_name       area  pop_total  pop_men  pop_women  men_2030  \
# 0           종로구       신교동    99144.0       1341      600        741       157
# 1           종로구       누상동   261803.6       3177     1429       1748       350
# 2           종로구       옥인동   414842.7       1854      842       1012       260
# 3           종로구       필운동    86207.7        981      448        533       122
# 4           종로구       사직동   284141.8       3166     1393       1773       325
# ..          ...       ...        ...        ...      ...        ...       ...
# 440         서초구       잠원동  3035875.4      50621    24212      26409      5567
# 441         강남구       삼성동  3193589.8      42657    20583      22074      5531
# 442         강남구      압구정동  2685131.5      30190    14013      16177      2739
# 443         송파구       신천동  4346310.8      37702    18034      19668      3663
# 444         용산구     원효로2가   131557.0       1731      903        828       380
#
#      women_2030  cctv_num  light_num  house_num  police_num
# 0           177        19         58          1           0
# 1           422        22        122          0           0
# 2           308        40        188          0           1
# 3           146        11         66          2           0
# 4           418        24        140          0           1
# ..          ...       ...        ...        ...         ...
# 440        6182       255        590          2           0
# 441        6182       697       1268         10           2
# 442        3349       129         44          0           1
# 443        4328       101        102          0           1
# 444         344        26        123          1           0
#
# [445 rows x 12 columns]

# %%
safe.to_csv("./concat_by_dong.csv", index=False)

# %%
crime = pd.read_csv("./data_final/서울시_범죄현황.csv")
crime
# Out:
#    city_name county_name  total_crime  total_arrest  murder_crime  \
# 0         서울         종로구         3138          3284             2
# 1         서울          중구         3071          2119             1
# 2         서울         용산구         2967          2093             5
# 3         서울         성동구         2194          1597             2
# 4         서울         광진구         3619          2498             6
# 5         서울        동대문구         3253          2231             4
# 6         서울         중랑구         3599          2671             2
# 7         서울         성북구         2749          2125             3
# 8         서울         강북구         2832          2343             5
# 9         서울         도봉구         2141          1569             3
# 10        서울         노원구         3896          2641             3
# 11        서울         은평구         3487          2658             4
# 12        서울        서대문구         2374          1605             5
# 13        서울         마포구         4096          2814             2
# 14        서울         양천구         3169          2130             2
# 15        서울         강서구         4663          3591             3
# 16        서울         구로구         3857          2732            11
# 17        서울         금천구         2577          1887             2
# 18        서울        영등포구         4819          3186             5
# 19        서울         동작구         2735          1741             2
# 20        서울         관악구         4879          3411            10
# 21        서울         서초구         4459          3098             3
# 22        서울         강남구         6947          5020            12
# 23        서울         송파구         5167          3409             2
# 24        서울         강동구         3711          2644             5
#
#     murder_arrest robbery_crime robbery_arrest  sex_crime  sex_arrest  \
# 0               3             8              8        228         988
# 1               2             5              4        194         123
# 2               3             7              7        280         238
# 3               2             2              2        125          97
# 4               5             -              -        230         174
# 5               4             2              2        125         106
# 6               2             2              2        150         121
# 7               3             1              1        158         129
# 8               4             5              6        177         147
# 9               3             -              -         70          54
# 10              3             3              1        180         151
# 11              4             5              4        176         146
# 12              4             6              6        157         144
# 13              2             2              1        436         368
# 14              2             3              3        114          92
# 15              3             7              7        261         195
# 16             11             8              9        217         145
# 17              1             3              3        127          87
# 18              6            10              9        327         237
# 19              3             5              5        212         107
# 20              8             9              8        327         279
# 21              2             3              3        431         328
# 22             10            11             10        667         534
# 23              2             5              6        290         220
# 24              6             5              5        157         134
#
#     theft_crime  theft_arrest  violence_crime  violence_arrest
# 0          1313           932            1587             1353
# 1          1365           724            1506             1266
# 2           978           508            1697             1337
# 3           979           538            1086              958
# 4          1670           831            1713             1488
# 5          1556           823            1566             1296
# 6          1508           882            1937             1664
# 7          1143           715            1444             1277
# 8           872           589            1773             1597
# 9           969           546            1099              966
# 10         1504           729            2206             1757
# 11         1497           946            1805             1558
# 12         1114           565            1092              886
# 13         1451           653            2205             1790
# 14         1474           781            1576             1252
# 15         1991          1185            2401             2201
# 16         1565           841            2056             1726
# 17         1118           662            1327             1134
# 18         2062           953            2415             1981
# 19         1195           588            1321             1038
# 20         1966          1050            2567             2066
# 21         1921          1024            2101             1741
# 22         2495          1207            3762             3259
# 23         2201          1033            2669             2148
# 24         1672           900            1872             1599

# %%
# '-' 값을 0으로 변환
crime['robbery_crime'] = crime['robbery_crime'].replace('-', '0')
crime['robbery_arrest'] = crime['robbery_arrest'].replace('-', '0')

# %%
crime = crime[['county_name', 'total_crime', "murder_crime", "robbery_crime", "sex_crime", "theft_crime", "violence_crime"]]
crime
# Out:
#    county_name  total_crime  murder_crime robbery_crime  sex_crime  \
# 0          종로구         3138             2             8        228
# 1           중구         3071             1             5        194
# 2          용산구         2967             5             7        280
# 3          성동구         2194             2             2        125
# 4          광진구         3619             6             0        230
# 5         동대문구         3253             4             2        125
# 6          중랑구         3599             2             2        150
# 7          성북구         2749             3             1        158
# 8          강북구         2832             5             5        177
# 9          도봉구         2141             3             0         70
# 10         노원구         3896             3             3        180
# 11         은평구         3487             4             5        176
# 12        서대문구         2374             5             6        157
# 13         마포구         4096             2             2        436
# 14         양천구         3169             2             3        114
# 15         강서구         4663             3             7        261
# 16         구로구         3857            11             8        217
# 17         금천구         2577             2             3        127
# 18        영등포구         4819             5            10        327
# 19         동작구         2735             2             5        212
# 20         관악구         4879            10             9        327
# 21         서초구         4459             3             3        431
# 22         강남구         6947            12            11        667
# 23         송파구         5167             2             5        290
# 24         강동구         3711             5             5        157
#
#     theft_crime  violence_crime
# 0          1313            1587
# 1          1365            1506
# 2           978            1697
# 3           979            1086
# 4          1670            1713
# 5          1556            1566
# 6          1508            1937
# 7          1143            1444
# 8           872            1773
# 9           969            1099
# 10         1504            2206
# 11         1497            1805
# 12         1114            1092
# 13         1451            2205
# 14         1474            1576
# 15         1991            2401
# 16         1565            2056
# 17         1118            1327
# 18         2062            2415
# 19         1195            1321
# 20         1966            2567
# 21         1921            2101
# 22         2495            3762
# 23         2201            2669
# 24         1672            1872

# %%
safe.columns
# Out:
# Index(['county_name', 'town_name', 'area', 'pop_total', 'pop_men', 'pop_women',
#        'men_2030', 'women_2030', 'cctv_num', 'light_num', 'house_num',
#        'police_num'],
#       dtype='object')

# %%
safe_gu = safe.groupby("county_name")[['area', 'pop_total', 'pop_men', 'pop_women',
       'men_2030', 'women_2030', 'cctv_num', 'light_num', 'house_num',
       'police_num']].sum()
safe_gu
# Out:
#                    area  pop_total  pop_men  pop_women  men_2030  women_2030  \
# county_name
# 강남구          39497597.1     549154   262618     286536     68860       77955
# 강동구          24590382.7     459389   224450     234939     60982       63912
# 강북구          23600408.1     287490   139141     148349     36477       36353
# 강서구          33942883.4     562528   269607     292921     83758       91473
# 관악구          29568368.9     481872   242598     239274    101562       94240
# 광진구          17062820.1     335335   161154     174181     54594       58908
# 구로구          20122908.3     392311   192252     200059     55561       56273
# 금천구          13020527.6     227457   114471     112986     37784       35149
# 노원구          35439122.0     497237   238609     258628     63984       62865
# 도봉구          20651010.0     306722   148670     158052     37896       37018
# 동대문구         14215912.2     340983   167230     173753     52342       53792
# 동작구          16356862.9     378360   182934     195426     61016       62197
# 마포구          23759686.1     362234   169193     193041     55669       66470
# 서대문구         17582821.1     304795   144734     160061     44244       48401
# 서초구          46965958.6     407768   194231     213537     50090       56664
# 성동구          16820149.0     277090   134390     142700     42096       44378
# 성북구          24577917.6     424916   203824     221092     58327       62017
# 송파구          33876575.0     653989   314189     339800     89783       99450
# 양천구          17406039.7     435548   212547     223001     52577       52623
# 영등포구         22275186.1     374985   183769     191216     61821       66291
# 용산구          19036534.5     212173   101791     110382     32201       34894
# 은평구          29710154.3     466474   221484     244990     61065       66836
# 종로구          22536925.8     137627    66452      71175     19544       20680
# 중구            9759468.4     121322    58651      62671     18376       19995
# 중랑구          18497134.6     382284   187392     194892     53345       54355
#
#              cctv_num  light_num  house_num  police_num
# county_name
# 강남구              6814      10210        112          14
# 강동구              2541       7503         43           9
# 강북구              2757       9776         25           9
# 강서구              2431       8635         36          11
# 관악구              4624      12401         53           9
# 광진구              3134       8971         15          10
# 구로구              4290       8015         31           8
# 금천구              2400       6269          9           5
# 노원구              1991       5288         27           8
# 도봉구              1395       6334          0           7
# 동대문구             2620      10307         39          10
# 동작구              2017       8835         27           7
# 마포구              1861       5710         34           8
# 서대문구             2860       7225         16           8
# 서초구              3688      11326         38          11
# 성동구              1255        215         15           9
# 성북구              3605       9982         34           9
# 송파구              2718       4325         42          10
# 양천구              3123       3800         13           8
# 영등포구             3756       9041         21           9
# 용산구              1484       9960         23           7
# 은평구              3531       9812         27           9
# 종로구              1608       8643         25          18
# 중구               2287       6064         25          14
# 중랑구              3748       9330         28           8

# %%
# 'county_name'을 기준으로 inner join
crime_gu = pd.merge(crime, safe_gu, on='county_name', how='inner')
crime_gu
# Out:
#    county_name  total_crime  murder_crime robbery_crime  sex_crime  \
# 0          종로구         3138             2             8        228
# 1           중구         3071             1             5        194
# 2          용산구         2967             5             7        280
# 3          성동구         2194             2             2        125
# 4          광진구         3619             6             0        230
# 5         동대문구         3253             4             2        125
# 6          중랑구         3599             2             2        150
# 7          성북구         2749             3             1        158
# 8          강북구         2832             5             5        177
# 9          도봉구         2141             3             0         70
# 10         노원구         3896             3             3        180
# 11         은평구         3487             4             5        176
# 12        서대문구         2374             5             6        157
# 13         마포구         4096             2             2        436
# 14         양천구         3169             2             3        114
# 15         강서구         4663             3             7        261
# 16         구로구         3857            11             8        217
# 17         금천구         2577             2             3        127
# 18        영등포구         4819             5            10        327
# 19         동작구         2735             2             5        212
# 20         관악구         4879            10             9        327
# 21         서초구         4459             3             3        431
# 22         강남구         6947            12            11        667
# 23         송파구         5167             2             5        290
# 24         강동구         3711             5             5        157
#
#     theft_crime  violence_crime        area  pop_total  pop_men  pop_women  \
# 0          1313            1587  22536925.8     137627    66452      71175
# 1          1365            1506   9759468.4     121322    58651      62671
# 2           978            1697  19036534.5     212173   101791     110382
# 3           979            1086  16820149.0     277090   134390     142700
# 4          1670            1713  17062820.1     335335   161154     174181
# 5          1556            1566  14215912.2     340983   167230     173753
# 6          1508            1937  18497134.6     382284   187392     194892
# 7          1143            1444  24577917.6     424916   203824     221092
# 8           872            1773  23600408.1     287490   139141     148349
# 9           969            1099  20651010.0     306722   148670     158052
# 10         1504            2206  35439122.0     497237   238609     258628
# 11         1497            1805  29710154.3     466474   221484     244990
# 12         1114            1092  17582821.1     304795   144734     160061
# 13         1451            2205  23759686.1     362234   169193     193041
# 14         1474            1576  17406039.7     435548   212547     223001
# 15         1991            2401  33942883.4     562528   269607     292921
# 16         1565            2056  20122908.3     392311   192252     200059
# 17         1118            1327  13020527.6     227457   114471     112986
# 18         2062            2415  22275186.1     374985   183769     191216
# 19         1195            1321  16356862.9     378360   182934     195426
# 20         1966            2567  29568368.9     481872   242598     239274
# 21         1921            2101  46965958.6     407768   194231     213537
# 22         2495            3762  39497597.1     549154   262618     286536
# 23         2201            2669  33876575.0     653989   314189     339800
# 24         1672            1872  24590382.7     459389   224450     234939
#
#     men_2030  women_2030  cctv_num  light_num  house_num  police_num
# 0      19544       20680      1608       8643         25          18
# 1      18376       19995      2287       6064         25          14
# 2      32201       34894      1484       9960         23           7
# 3      42096       44378      1255        215         15           9
# 4      54594       58908      3134       8971         15          10
# 5      52342       53792      2620      10307         39          10
# 6      53345       54355      3748       9330         28           8
# 7      58327       62017      3605       9982         34           9
# 8      36477       36353      2757       9776         25           9
# 9      37896       37018      1395       6334          0           7
# 10     63984       62865      1991       5288         27           8
# 11     61065       66836      3531       9812         27           9
# 12     44244       48401      2860       7225         16           8
# 13     55669       66470      1861       5710         34           8
# 14     52577       52623      3123       3800         13           8
# 15     83758       91473      2431       8635         36          11
# 16     55561       56273      4290       8015         31           8
# 17     37784       35149      2400       6269          9           5
# 18     61821       66291      3756       9041         21           9
# 19     61016       62197      2017       8835         27           7
# 20    101562       94240      4624      12401         53           9
# 21     50090       56664      3688      11326         38          11
# 22     68860       77955      6814      10210        112          14
# 23     89783       99450      2718       4325         42          10
# 24     60982       63912      2541       7503         43           9

# %%
crime_gu.to_csv("./concat_by_gu.csv", index=False)
